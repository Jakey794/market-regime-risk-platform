# %% [markdown]
# # 04 Regime Model Comparison
# Package APIs only; no financial logic is reimplemented here.

# %%
from mrrp.data.cache import load_parquet
from mrrp.models.build_models import fit_configured_models

features = load_parquet("../data/processed/regime_features_scaled.parquet")
results = fit_configured_models(features, config_path="../configs/regime_models.yaml")
