# %% [markdown]
# # 05 Backtest Analysis
# Package APIs only; no financial logic is reimplemented here.

# %%
from mrrp.backtest.run_backtest import main

# Invoke the same package entry point used by `make backtest` when artifacts exist.
# This notebook intentionally contains no duplicated backtest math.
main
