# %% [markdown]
# # 06 Failure Analysis
#
# Documented failure modes for the regime / stress / backtest research stack.
# This notebook is qualitative and points to package outputs; it does not claim alpha.

# %% [markdown]
# ## Failure modes covered
#
# 1. Regime-label instability across seeds/specs
# 2. State-identification ambiguity without economic relabeling
# 3. Window sensitivity of trailing features
# 4. Number-of-state sensitivity
# 5. Non-stationarity of market risk regimes
# 6. ETF proxy limitations
# 7. Free-data limitations and history gaps
# 8. Crisis correlation breakdown
# 9. VaR/CVaR limitations
# 10. Transaction-cost model simplicity
# 11. Bull-market underperformance of defensive rules
# 12. Backtest overfitting and model-selection bias
#
# See `reports/final_research_report.md` for the written analysis.

# %%
from pathlib import Path
import pandas as pd

comparison = Path("data/processed/regime_models/model_comparison.csv")
if comparison.exists():
    display(pd.read_csv(comparison).head(20))
else:
    print("Run `make models` to generate model_comparison.csv")
